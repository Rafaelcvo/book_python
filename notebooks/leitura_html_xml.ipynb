# %% [markdown]
# # Leitura de arquivo HTML da agência governamental FDIC dos Estados Unidos, que mostra falência de bancos.

# %%
import numpy as np
import pandas as pd

# %%
tables = pd.read_html('/home/rafael/git/book_python/examples/fdic_failed_bank_list.html')

# %%
failures = tables[0]

# %%
close_timestamps= pd.to_datetime(failures['Closing Date'])
close_timestamps.dt.year.value_counts()
# Out:
# 2010    157
# 2009    140
# 2011     92
# 2012     51
# 2008     25
# 2013     24
# 2014     18
# 2002     11
# 2015      8
# 2016      5
# 2004      4
# 2001      4
# 2007      3
# 2003      3
# 2000      2
# Name: Closing Date, dtype: int64

# %% [markdown]
# # Leitura de arquivo xml do MTA.

# %%
#pág 236
from lxml import objectify

# %%
path = '/home/rafael/git/book_python/datasets/lista-completa-servicos.xml'

# %%
parsed = objectify.parse(open(path))

# %%
root = parsed.getroot()

# %% [markdown]
# # Formato de dados binários

# %%
frame = pd.read_csv('/home/rafael/git/book_python/datasets/anatel.csv',sep=';',encoding='latin-1')

# %%
frame.to_pickle('examples/frame_pickle')

# %%
pd.read_pickle('examples/frame_pickle')
# Out:
#      DataExtracao   Ano  Mes          CanalEntrada       Condicao  \
# 0      2017-01-08  2016    1  Aplicativo Móvel               Nova
# 1      2017-01-08  2016    1  Aplicativo Móvel               Nova
# 2      2017-01-08  2016    1  Aplicativo Móvel               Nova
# 3      2017-01-08  2016    1  Aplicativo Móvel               Nova
# 4      2017-01-08  2016    1  Aplicativo Móvel               Nova
# 5      2017-01-08  2016    1  Aplicativo Móvel               Nova
# 6      2017-01-08  2016    1  Aplicativo Móvel               Nova
# 7      2017-01-08  2016    1  Aplicativo Móvel               Nova
# 8      2017-01-08  2016    1  Aplicativo Móvel           Reaberta
# 9      2017-01-08  2016    1           Call Center           Nova
# 10     2017-01-08  2016    1           Call Center           Nova
# 11     2017-01-08  2016    1           Call Center           Nova
# 12     2017-01-08  2016    1           Call Center           Nova
# ...
